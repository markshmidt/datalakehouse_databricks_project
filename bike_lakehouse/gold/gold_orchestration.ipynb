# %% [markdown]
# Data orchestration for gold layer: single entry point

# %%
notebooks = [
    "./Gold_customers",
    "./Gold_products",
    "./Gold_fact_sales"
]

for nb in notebooks:
    print(f"Running {nb}")
    dbutils.notebook.run(nb, timeout_seconds=0)
