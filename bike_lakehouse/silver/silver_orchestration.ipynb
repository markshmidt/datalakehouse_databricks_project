# %%
notebooks = [
    "./Silver_crm_cust_info",
    "./Silver_crm_prd_info",
    "./Silver_crm_sales_details",
    "./Silver_erp_cust",
    "./Silver_",
    "./Silver_erp_px"
]

for nb in notebooks:
    print(f"Running {nb}")
    dbutils.notebook.run(nb, timeout_seconds=0)
