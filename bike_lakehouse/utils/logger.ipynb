# %%
from datetime import datetime

def log_event(layer, table, status, message, rows=None):
    ts = datetime.now().isoformat()
    print(f"[{ts}] [{layer}] [{table}] [{status}] rows={rows} msg={message}")
